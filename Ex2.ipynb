# %%
import pandas as pd
df=pd.read_csv('C:/Users/Yerassyl/Desktop/data mining/shanghai_ranking_2024.csv')
print(df.isnull().sum())
df_drop=df.dropna()
df_fill=df.fillna(1)
print(df_fill)
df_ffill = df.ffill()  
print(df_ffill)
df_bfill = df.bfill()  
print(df_bfill)
# Out:
# Rank                       0
# University_Name            0
# National/Regional Rank     0
# Alumni                     0
# Award                      0
# Hici                       0
# N&S                       11
# PUB                        0
# PCP                        0
# dtype: int64
#          Rank                              University_Name  \
# 0           1                           Harvard University
# 1           2                          Stanford University
# 2           3  Massachusetts Institute of Technology (MIT)
# 3           4                      University of Cambridge
# 4           5           University of California, Berkeley
# ..        ...                                          ...
# 995  901-1000                     Universidad Andrés Bello
# 996  901-1000                         University of Lahore
# 997  901-1000                          Linnaeus University
# 998  901-1000                      University of Wuppertal
# ...
